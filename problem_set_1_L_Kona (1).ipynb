# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"US/Eastern\"")

# %%
hex_project_id = _hex_json.loads("\"e2e04e1a-43d3-4920-a5fd-375884cf10b0\"")

# %%
hex_project_name = _hex_json.loads("\"problem_set_1_L_Kona\"")

# %%
hex_status = _hex_json.loads("\"\"")

# %%
hex_categories = _hex_json.loads("[]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %%
# Import packages
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np
import altair as alt
import plotly.express as px

# %% [markdown]
# #### 1. Load traffic stops data and create a dataframe called stops and check the columns and their types

# %%
stops = pd.read_csv(r'Officer_Traffic_Stops.csv')
stops.dtypes
# Out:
# Month_of_Stop               object
# Reason_for_Stop             object
# Officer_Race                object
# Officer_Gender              object
# Officer_Years_of_Service     int64
# Driver_Race                 object
# Driver_Ethnicity            object
# Driver_Gender               object
# Driver_Age                   int64
# Was_a_Search_Conducted      object
# Result_of_Stop              object
# CMPD_Division               object
# ObjectID                     int64
# CreationDate                object
# Creator                     object
# EditDate                    object
# Editor                      object
# dtype: object

# %% [markdown]
# #### 2. View the data by just typing the dataframe name

# %%
stops
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month_of_Stop</th>
#       <th>Reason_for_Stop</th>
#       <th>Officer_Race</th>
#       <th>Officer_Gender</th>
#       <th>Officer_Years_of_Service</th>
#       <th>Driver_Race</th>
#       <th>Driver_Ethnicity</th>
#       <th>Driver_Gender</th>
#       <th>Driver_Age</th>
#       <th>Was_a_Search_Conducted</th>
#       <th>Result_of_Stop</th>
#       <th>CMPD_Division</th>
#       <th>ObjectID</th>
#       <th>CreationDate</th>
#       <th>Creator</th>
#       <th>EditDate</th>
#       <th>Editor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017/06</td>
# ...

# %% [markdown]
# #### 3. Check the data using df.info()

# %%
stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68488 entries, 0 to 68487
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month_of_Stop             68488 non-null  object
#  1   Reason_for_Stop           68488 non-null  object
#  2   Officer_Race              68488 non-null  object
#  3   Officer_Gender            68488 non-null  object
#  4   Officer_Years_of_Service  68488 non-null  int64
#  5   Driver_Race               68488 non-null  object
#  6   Driver_Ethnicity          68488 non-null  object
#  7   Driver_Gender             68488 non-null  object
#  8   Driver_Age                68488 non-null  int64
#  9   Was_a_Search_Conducted    68488 non-null  object
#  10  Result_of_Stop            68488 non-null  object
#  11  CMPD_Division             67532 non-null  object
#  12  ObjectID                  68488 non-null  int64
# ...

# %% [markdown]
# You will notice object and int64 this may not be what we would like so lets remember that
#
# Let's consider our target variable: `Was_a_Search_Conducted`.
#
# **Plot** a bar chart that counts the number of records by `Was_a_Search_Conducted`.

# %%
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# #### 4. Plot a bar chart that counts the number of records by `Was_a_Search_Conducted`.

# %%
stops_search_counts = stops['Was_a_Search_Conducted'].value_counts().rename_axis('Was_a_Search_Conducted').reset_index(name='counts')


fig = px.bar(stops_search_counts, 
x="Was_a_Search_Conducted", 
y="counts", 
# color="counts", 
title="CMPD traffic stops - Search Conducted Counts", text_auto=True )
fig.update_layout(
    autosize=False,
    width=500,
    height=500,
    template="ggplot2"
)

fig.update_yaxes(automargin=True)
fig.update_traces(width=.5)
fig.show()

# %% [markdown]
# Next, let's consider the age range of the driver.
# #### 5. Plot a histogram of `Driver_Age`. Determine an appropriate number of bins.

# %%
## Histogram
fig = px.histogram(stops, x="Driver_Age",  title='Histogram of Driver Age with 30 bins', nbins=30, text_auto='.3s')
fig.show()

# %%
Driver_Age = stops['Driver_Age']

fig2 = plt.figure(figsize=(12,6))

plt.hist(Driver_Age, bins="auto", color="#0504aa", alpha=0.7, rwidth=0.85)
plt.grid(axis="y", alpha=0.75)
plt.xlabel("Driver Age")
plt.ylabel("count")
plt.title("Histogram with 'auto' bins using matplotlib")

counts, bins = np.histogram(Driver_Age, bins="auto")
print("Number of bins: ", len(bins))
plt.show()
# Out:
# Number of bins:  104

# %%
## Histogram

Driver_Age = stops['Driver_Age']
n_data = len(Driver_Age)

# Number of bins is the square root of number of data points: n_bins
n_bins = np.sqrt(n_data)
n_bins = int(n_bins)
print(f"Number of bins: {n_bins}")


# Plot the histogram
fig = plt.figure(figsize=(12,6))

_ = plt.hist(Driver_Age, bins=n_bins, color='green')
_ = plt.xlabel('Driver Age', labelpad=20)
_ = plt.ylabel('count', labelpad=20)
_ = plt.title("Bins computed using the Square root rule")
# Out:
# Number of bins: 261

# %% [markdown]
# #### 6. Once you go above (around) 40-50 bins, you'll notice some points stick out.
#
# What is happening? xxxxx

# %% [markdown]
# - Histograms with large bin widths that group data into only a few bins. This does not give good information about variability in the distribution.
#
# - Histograms with small bin widths that group data into lots of bins. This does not help us see the pattern in the data.
#
#
# Impact of more / less no. of bins doesn't represent the data well.
#
# **bins='auto' :: **Matplotlib determines bins using Sturges and Freedman-Diaconis bin choice methods.
#
# So, histogram with 20-30 bins would give appropriate pattern for this data.

# %% [markdown]
# #### 7. Plot a box plot with `Was_a_Search_Conducted` on the x-axis and `Driver_Age` on the y-axis.

# %%
fig = px.box(stops, x="Was_a_Search_Conducted", y="Driver_Age", 
title="Search counducted w.r.t Driver Age - Box Plot")
fig.show()

# %% [markdown]
# #### 8. Plot a violin plot where the fill is the response variable "Was_a_search_conducted"
# https://altair-viz.github.io/gallery/violin_plot.html

# %%
fig = px.violin(stops, x="Was_a_Search_Conducted", y="Driver_Age", 
box=True
,title="Search counducted w.r.t Driver Age - Violin Plot"
)
# fig.update_traces(box_visible=True, meanline_visible=True)

fig.show()

# %% [markdown]
# #### 8b. From the plots above, do you think the age of the driver is a significant factor in whether a search was conducted? Why or why not? xxxxx

# %% [markdown]
# **Ans::**
#
# Yes, Age of drivers seems to be impacting for officer Traffic stops and search conducted.
#
# While 25-45 age range drivers are stopped, a larger proportion of drivers whose age range 23-35 had undergone searched.

# %% [markdown]
# ## Date of stop
#
# Let's plot the number of stops by time.
#
# Recalling part one, the `Month_of_Stop` variable is a character, not a date variable. The datatime's are simply when the data was collected; not when the stop occurred. Therefore, we'll need to convert the `Month_of_Stop` variable from a character to a Date format.
#
# Uncomment out the next 4 code blocks these are given to you but please study and know what they do

# %%
stops['Month_of_Stop']
# Out:
# 0        2017/06
# 1        2017/06
# 2        2017/06
# 3        2017/06
# 4        2017/06
#           ...
# 68483    2017/06
# 68484    2017/06
# 68485    2017/06
# 68486    2017/06
# 68487    2017/06
# Name: Month_of_Stop, Length: 68488, dtype: object

# %%
type(stops.Month_of_Stop[0])
# Out:
# str

# %%
stops['Month_of_Stop'] = stops['Month_of_Stop'].astype('datetime64[ns]')

# %%
stops['Month_of_Stop'] = pd.to_datetime(stops['Month_of_Stop'], format='%y%m%d')

# %%
stops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68488 entries, 0 to 68487
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month_of_Stop             68488 non-null  datetime64[ns]
#  1   Reason_for_Stop           68488 non-null  object
#  2   Officer_Race              68488 non-null  object
#  3   Officer_Gender            68488 non-null  object
#  4   Officer_Years_of_Service  68488 non-null  int64
#  5   Driver_Race               68488 non-null  object
#  6   Driver_Ethnicity          68488 non-null  object
#  7   Driver_Gender             68488 non-null  object
#  8   Driver_Age                68488 non-null  int64
#  9   Was_a_Search_Conducted    68488 non-null  object
#  10  Result_of_Stop            68488 non-null  object
#  11  CMPD_Division             67532 non-null  object
#  12  ObjectID                  68488 non-null  int64
# ...

# %%
stops
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month_of_Stop</th>
#       <th>Reason_for_Stop</th>
#       <th>Officer_Race</th>
#       <th>Officer_Gender</th>
#       <th>Officer_Years_of_Service</th>
#       <th>Driver_Race</th>
#       <th>Driver_Ethnicity</th>
#       <th>Driver_Gender</th>
#       <th>Driver_Age</th>
#       <th>Was_a_Search_Conducted</th>
#       <th>Result_of_Stop</th>
#       <th>CMPD_Division</th>
#       <th>ObjectID</th>
#       <th>CreationDate</th>
#       <th>Creator</th>
#       <th>EditDate</th>
#       <th>Editor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2017-06-01</td>
# ...

# %% [markdown]
# #### 9. Plot a line chart with the number of traffic stops for each month (hint: think about the aggregations we did in class).

# %%
## Create a dataframe named stops_count for this graph that has a column named Month_of_Stop 
## Also create a column named count representing the ammount of stops per month  https://sparkbyexamples.com/pandas/pandas-groupby-count-examples/

stops_count = stops['Month_of_Stop'].value_counts().rename_axis('Month_of_Stop').reset_index(name='counts')
stops_count = stops_count.sort_values(by="Month_of_Stop", ascending=True)
stops_count
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month_of_Stop</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>13</th>
#       <td>2016-01-01</td>
#       <td>2819</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2016-02-01</td>
#       <td>2841</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2016-03-01</td>
#       <td>3238</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2016-04-01</td>
#       <td>3505</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2016-05-01</td>
#       <td>2555</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2016-06-01</td>
# ...

# %%
## Line chart

fig = px.line(stops_count, 
x="Month_of_Stop", 
y="counts", 
title="Frequency of Stops per Month"
)
fig.update_layout(
    autosize=False,
    # width=500,
    height=500,
    template="ggplot2"
)

fig.update_yaxes(automargin=True)
fig.show()

# %% [markdown]
# #### 10. What is the trend (i.e., long term rate of change) of the number of traffic stops in Charlotte? xxxxx

# %% [markdown]
# **Ans::** This is a fluctuating pattern, with peaks in April - July months (Summer) and a subsequent decline in Sept and Oct (Fall)

# %% [markdown]
# #### 11. Plot the same plot but add in `.facet()` by the `Reason_for_Stop` variable.

# %%
## create the dataframe that groups by month and reason for stop 
stops_facet = stops.groupby(['Month_of_Stop','Reason_for_Stop'])['ObjectID'].count().reset_index(name='counts')

stops_facet = stops_facet.sort_values(by="Month_of_Stop", ascending=True)
stops_facet
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month_of_Stop</th>
#       <th>Reason_for_Stop</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-01-01</td>
#       <td>CheckPoint</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2016-01-01</td>
#       <td>Driving While Impaired</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2016-01-01</td>
#       <td>Investigation</td>
#       <td>71</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2016-01-01</td>
#       <td>Other</td>
#       <td>84</td>
#     </tr>
#     <tr>
# ...

# %%
## Facet chart https://stackoverflow.com/questions/64770801/python-altair-facet-line-plot-with-multiple-variables

alt.Chart(stops_facet, title="Stops per Month by 'Reason_for_Stop' facet variable").mark_line().encode(
    x='Month_of_Stop:T',
    y='counts:Q',
    facet=alt.Facet('Reason_for_Stop:O').columns(3)
)

# %% [markdown]
# #### 12. What is a problem with this plot? xxxxx

# %% [markdown]
# Issue::
#
# A Facet chart is used to visualize a distribution and compare among multiple variables/dimensions.
#
# All charts using the same X and Y axis. Cannot display their axis or scale independently.
#
#
#
# Solution::
#
# Creating a facet_wrap(), we can style and scale each subplot as per its measure values independently.

# %% [markdown]
# To address this problem, you will need to figure out how to adjust the scale. To do this, you need to use altairs documentation to see whether there is a function that could help you.
#
# https://altair-viz.github.io/user_guide/scale_resolve.html
#
# #### 13. What parameter allows you to modify the scales of `facet_wrap`?
#
# **Ans::** 'Chart.resolve_scale()'
#
#
# For facet_wrap(), you can control whether the position scales are the same in all panels (fixed) or allowed to vary between panels (free) with the resolve_scale parameter

# %% [markdown]
# #### 14. Plot the same plot but with a free y-axis scale. (This may take some research but very findable)

# %%
# Updated Facet Chart
alt.Chart(stops_facet).mark_line().encode(
    x='Month_of_Stop:T',
    y='counts:Q',
    facet=alt.Facet('Reason_for_Stop:O').columns(3)
).resolve_scale(
    y='independent'
)

# %% [markdown]
# #### 15. Which type of police stop has had the most volatility (i.e., big swings in number of stops)? xxxx
#
# **Ans::** Vehicle Regulatory

# %% [markdown]
# #### 16. What is one problem with allowing the y-axis be free? xxxxx
#
# **Ans::**
#
# If the scales = "free_y" argument is added, their height will be proportional to the length of the y scale;
#
# Similarly, if "free_x" their width will be proportional to the length of the x scale; or if "free" both height and width will vary.
#
# Using facet_wrap, each plot is displayed independently, and it can "free" its x-axis and y-axis.

# %% [markdown]
# Small multiples tends to be less effective when each of the variables are on different scales or magnitudes.
#
# Let's consider instead CMPD traffic stops but by CMPD division. These are more even spread by division than the type of stop.
#
# #### 17. Plot a line chart for stops by `Date` but grouped by Division instead of reason

# %%
# Facet plot for division stops

stops_division = stops.groupby(['Month_of_Stop','CMPD_Division'])['ObjectID'].count().reset_index(name='counts')

stops_division = stops_division.sort_values(by="Month_of_Stop", ascending=True)
stops_division
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month_of_Stop</th>
#       <th>CMPD_Division</th>
#       <th>counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2016-01-01</td>
#       <td>Central Division</td>
#       <td>166</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2016-01-01</td>
#       <td>Westover Division</td>
#       <td>235</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2016-01-01</td>
#       <td>University City Division</td>
#       <td>195</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2016-01-01</td>
#       <td>Steele Creek Division</td>
#       <td>258</td>
# ...

# %%
alt.Chart(stops_division).mark_line().encode(
    x='Month_of_Stop:T',
    y='counts:Q',
    facet=alt.Facet('CMPD_Division:O').columns(3)
).resolve_scale(
    y='independent'
)

# %% [markdown]
# #### 18. What are three observations you can make about the number of police stops by divison? (hint: just write about what's in the data.)
#
#
# **Ans::**
# 1. Central, Freedom, Metro, Steele Creek and University City Divisions have similar trend of stops during that month of year.
#
# And these have counts < 300 (except Steele Creek, Aug 2017 = 416 count)
#
# 2. Most of the Divisions has the highest spikes in Jun-Jul of both years (Summers)
#
# 3. Least during Sept-Oct months of both years
#
# 4. Eastway and Providence has more counts >350, recorded from Nov 2016 to 2017 following
